# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly_express as px
from sklearn import metrics
# %matplotlib inline

# %%
df = pd.read_csv('wine.csv', names = ['Cultivator', 'Alcohol', 'Malic_Acid', 'Ash', 'Alcalinity_of_Ash', 'Magnesium', 'Total_phenols', 'Falvanoids', 'Nonfalvanoid_phenols', 'Proanthocyanins', 'Color_intensity', 'Hue', 'OD280', 'Proline'])

# %%
df.shape
# Out:
# (178, 14)

# %%
df['Cultivator'].value_counts()
# Out:
# 2    71
# 1    59
# 3    48
# Name: Cultivator, dtype: int64

# %%
df.describe().transpose()
# Out:
#                       count        mean         std     min       25%  \
# Cultivator            178.0    1.938202    0.775035    1.00    1.0000
# Alcohol               178.0   13.000618    0.811827   11.03   12.3625
# Malic_Acid            178.0    2.336348    1.117146    0.74    1.6025
# Ash                   178.0    2.366517    0.274344    1.36    2.2100
# Alcalinity_of_Ash     178.0   19.494944    3.339564   10.60   17.2000
# Magnesium             178.0   99.741573   14.282484   70.00   88.0000
# Total_phenols         178.0    2.295112    0.625851    0.98    1.7425
# Falvanoids            178.0    2.029270    0.998859    0.34    1.2050
# Nonfalvanoid_phenols  178.0    0.361854    0.124453    0.13    0.2700
# Proanthocyanins       178.0    1.590899    0.572359    0.41    1.2500
# Color_intensity       178.0    5.058090    2.318286    1.28    3.2200
# Hue                   178.0    0.957449    0.228572    0.48    0.7825
# ...

# %%
df.head(10)
# Out:
#    Cultivator  Alcohol  Malic_Acid   Ash  Alcalinity_of_Ash  Magnesium  \
# 0           1    14.23        1.71  2.43               15.6        127
# 1           1    13.20        1.78  2.14               11.2        100
# 2           1    13.16        2.36  2.67               18.6        101
# 3           1    14.37        1.95  2.50               16.8        113
# 4           1    13.24        2.59  2.87               21.0        118
# 5           1    14.20        1.76  2.45               15.2        112
# 6           1    14.39        1.87  2.45               14.6         96
# 7           1    14.06        2.15  2.61               17.6        121
# 8           1    14.83        1.64  2.17               14.0         97
# 9           1    13.86        1.35  2.27               16.0         98
#
#    Total_phenols  Falvanoids  Nonfalvanoid_phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Cultivator            178 non-null    int64
#  1   Alcohol               178 non-null    float64
#  2   Malic_Acid            178 non-null    float64
#  3   Ash                   178 non-null    float64
#  4   Alcalinity_of_Ash     178 non-null    float64
#  5   Magnesium             178 non-null    int64
#  6   Total_phenols         178 non-null    float64
#  7   Falvanoids            178 non-null    float64
#  8   Nonfalvanoid_phenols  178 non-null    float64
#  9   Proanthocyanins       178 non-null    float64
#  10  Color_intensity       178 non-null    float64
#  11  Hue                   178 non-null    float64
#  12  OD280                 178 non-null    float64
#  13  Proline               178 non-null    int64
# dtypes: float64(11), int64(3)
# ...

# %%
sns.pairplot(df, hue = 'Cultivator', diag_kind = 'kde')

# %%
df.isnull().sum()
# Out:
# Cultivator              0
# Alcohol                 0
# Malic_Acid              0
# Ash                     0
# Alcalinity_of_Ash       0
# Magnesium               0
# Total_phenols           0
# Falvanoids              0
# Nonfalvanoid_phenols    0
# Proanthocyanins         0
# Color_intensity         0
# Hue                     0
# OD280                   0
# Proline                 0
# dtype: int64

# %%
df.dtypes
# Out:
# Cultivator                int64
# Alcohol                 float64
# Malic_Acid              float64
# Ash                     float64
# Alcalinity_of_Ash       float64
# Magnesium                 int64
# Total_phenols           float64
# Falvanoids              float64
# Nonfalvanoid_phenols    float64
# Proanthocyanins         float64
# Color_intensity         float64
# Hue                     float64
# OD280                   float64
# Proline                   int64
# dtype: object

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_predict, cross_val_score

# %%
# Seperating independent and dependent variables

x = df.drop('Cultivator', axis = 1)
y = df['Cultivator']

# %%
# Splitting the variables for training and testing

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.30, random_state = 1)

# %%
# Training the model

nb = GaussianNB()
nb.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
# Getting the model accuracy

print ('Model accuracy: {}%'.format(nb.score(x_test, y_test) * 100))
# Out:
# Model accuracy: 98.14814814814815%

# %%
# Predicting the value and printing the classification report and confusion matrix

pred = nb.predict(x_test)

print (metrics.classification_report(y_test, pred))
print (metrics.confusion_matrix(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.96      1.00      0.98        23
#            2       1.00      0.95      0.97        19
#            3       1.00      1.00      1.00        12
#
#     accuracy                           0.98        54
#    macro avg       0.99      0.98      0.98        54
# weighted avg       0.98      0.98      0.98        54
#
# [[23  0  0]
#  [ 1 18  0]
#  [ 0  0 12]]

# %%
# K-fold cross validation --> Used when number of data points is less

score = cross_val_score(nb, x_train, y_train, cv = 10)
print ('Cross validation score:', score, score)
print ('Average score:', np.average(score))
# Out:
# Cross validation score: [1.         0.92307692 1.         1.         0.91666667 1.
#  0.91666667 1.         1.         0.91666667] [1.         0.92307692 1.         1.         0.91666667 1.
#  0.91666667 1.         1.         0.91666667]
# Average score: 0.9673076923076922
